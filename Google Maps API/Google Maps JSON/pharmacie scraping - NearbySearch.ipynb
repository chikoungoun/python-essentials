# %%
import requests
import json
import csv
import time

# %%
with open('../api_key.txt') as f:
    api_key = f.readline()
    f.close

# %% [markdown]
# ### Nearby Search

# %%
url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=12.9538477,77.3507442&radius=20000&type=atm"

# %%
url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?"

# %%
location = "33.589886, -7.603869"

# %%
# en mètres
radius = 26000

# %%
# type d'endroit à rechercher
place_type = "pharmacy"

# %%
language = "fr"

# %%
r = requests.get(url + '&location=' +str(location) +'&radius='+str(radius) + '&type='+place_type+'&language='+language+'&key=' + api_key)

# %%
response = r.json()

# %%
response
# Out:
# {'html_attributions': [],
#  'next_page_token': 'CqQCHAEAAFeKcnfLnw4waZWqtTpciJ8HsLw5gdTV7cgLa3ut9QblzjEXfUGtQczepCUmaOsjDlGsnIGo8MI1OsQOx-Z2AVPVg3Mi_-09M7sGtCnqI1cfXjFxImJTa0_ZqZIpau7D0fJdjHhxVm-mcWIGmWupDKHwg_tvmv_uv1Fu8UgVNgG08fh7mZ4OEW9-fDWoHN1zUs1OsPIRHs-2j_ALSKe4VaQS4qigT3lF3bAHJYQo9PQifX_bxgfJ25SWY3LTxXZpMuzqWnKuoiUX1hfiw7M9rvUVTR4njjaWPhf1xfs1cpwJGh41xOW5ecFNZSEBPM01a0Iu_c86IUQO5PXBK9EqENEpVzK_NR0-joVtukUTzrqghRiQcmIeWkzmYwAkUa4gZRIQbNuJBI8ULLf3hC5FZ0qINRoULRFdlmGx-lFzlPS8P6TsHRKRkj4',
#  'results': [{'geometry': {'location': {'lat': 33.59472820000001,
#      'lng': -7.608590100000001},
#     'viewport': {'northeast': {'lat': 33.59609483029149,
#       'lng': -7.607245169708499},
#      'southwest': {'lat': 33.59339686970849, 'lng': -7.609943130291503}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#    'id': 'b24ed0c4028f0d44548e815e3f12c47647bc912e',
#    'name': 'Pharmacie Safir',
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100035392070340772750/photos">Ahmed Amine</a>'],
#      'photo_reference': 'CmRaAAAACRXFKcK7a3zU9zjZpJCisEqn6gk1ec43JnlTyJtat4JbAHLCS8btATL256h3xcjusZuygx_wfJo9ruFG5DuHKEhP6t9RPF_sYQiEQlSRJpybKqmqJbimkT1mB5wCp1YcEhBRYKM6nt4GtVmwpfOPMdJQGhSnvPM0zlURppfgis92i3jjtTvujg',
#      'width': 3024}],
#    'place_id': 'ChIJPXQ4IGPNpw0RDsghfmDSyxY',
#    'plus_code': {'compound_code': 'H9VR+VH Casablanca, Maroc',
#     'global_code': '8C5JH9VR+VH'},
#    'rating': 3.6,
#    'reference': 'ChIJPXQ4IGPNpw0RDsghfmDSyxY',
#    'scope': 'GOOGLE',
#    'types': ['pharmacy',
#     'health',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 7,
#    'vicinity': 'Casablanca'},
#   {'geometry': {'location': {'lat': 33.5720615, 'lng': -7.5942725},
#     'viewport': {'northeast': {'lat': 33.5734375802915,
#       'lng': -7.592895869708498},
#      'southwest': {'lat': 33.5707396197085, 'lng': -7.595593830291502}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#    'id': 'a7e67edb7beec34bb7aa773df2d4070250045113',
#    'name': "Pharmacie de l'Union",
#    'photos': [{'height': 1128,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107530581315382761553/photos">BENALI CHAKIB</a>'],
#      'photo_reference': 'CmRaAAAAhDZxjH1qQxo-SSZ1ojSK19XdlXKp4QJi7VoTvqB_aB5uRM_d3sykbSZFjRKHswcVcNHQgDkWMWQzB-2WdjKn0V9SBMeIbJBF-Zw-ViVM0i9SvnMxm4hADbrhpMgVEX7WEhC3KIUJ0Y6iPVsq1vGOKOiEGhToTdXthLVuJSXZTJNt7fgno25dOw',
#      'width': 1032}],
#    'place_id': 'ChIJDTwD2UjNpw0RT-RM53KTizs',
#    'plus_code': {'compound_code': 'HCC4+R7 Casablanca, Maroc',
#     'global_code': '8C5JHCC4+R7'},
#    'rating': 5,
#    'reference': 'ChIJDTwD2UjNpw0RT-RM53KTizs',
#    'scope': 'GOOGLE',
#    'types': ['pharmacy',
#     'health',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 4,
#    'vicinity': 'Casablanca'},
#   {'geometry': {'location': {'lat': 33.5769354, 'lng': -7.636434099999999},
#     'viewport': {'northeast': {'lat': 33.5782523302915,
#       'lng': -7.635067619708497},
#      'southwest': {'lat': 33.57555436970851, 'lng': -7.637765580291502}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#    'id': '3125f5493643e7c370a65a41273883d578c2e710',
#    'name': 'Pharmacie Mehdi صيدلية مهدي',
#    'opening_hours': {'open_now': False},
#    'place_id': 'ChIJz7UO0MbSpw0R9jXEOaPBWT8',
#    'plus_code': {'compound_code': 'H9G7+QC Casablanca, Maroc',
#     'global_code': '8C5JH9G7+QC'},
#    'rating': 3,
#    'reference': 'ChIJz7UO0MbSpw0R9jXEOaPBWT8',
#    'scope': 'GOOGLE',
#    'types': ['pharmacy',
#     'health',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 2,
#    'vicinity': 'Casablanca'},
#   {'geometry': {'location': {'lat': 33.5718648, 'lng': -7.653467500000001},
#     'viewport': {'northeast': {'lat': 33.5731966302915,
#       'lng': -7.652132469708497},
#      'southwest': {'lat': 33.5704986697085, 'lng': -7.654830430291502}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#    'id': '646141bc685f6eca94ca3b4b2dfeece62ac0926b',
#    'name': 'Kenza كنزة',
#    'place_id': 'ChIJjfnUF9jSpw0RxzgdEPowg_4',
#    'plus_code': {'compound_code': 'H8CW+PJ Casablanca, Maroc',
#     'global_code': '8C5JH8CW+PJ'},
#    'rating': 4.5,
#    'reference': 'ChIJjfnUF9jSpw0RxzgdEPowg_4',
#    'scope': 'GOOGLE',
#    'types': ['pharmacy',
#     'health',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 2,
#    'vicinity': 'Casablanca'},
#   {'geometry': {'location': {'lat': 33.5710826, 'lng': -7.660144900000001},
#     'viewport': {'northeast': {'lat': 33.5723704302915,
#       'lng': -7.658744369708497},
#      'southwest': {'lat': 33.5696724697085, 'lng': -7.661442330291502}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#    'id': 'e40f0aa0164bc6db29ecd42a0e6d992e8d0d46fd',
#    'name': 'Pharmacie Araucaria',
#    'place_id': 'ChIJxeUMBybTpw0R1YFidukmccw',
#    'plus_code': {'compound_code': 'H8CQ+CW Casablanca, Maroc',
#     'global_code': '8C5JH8CQ+CW'},
#    'reference': 'ChIJxeUMBybTpw0R1YFidukmccw',
#    'scope': 'GOOGLE',
#    'types': ['pharmacy',
#     'health',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'vicinity': 'Casablanca'},
#   {'geometry': {'location': {'lat': 33.60608839999999,
#      'lng': -7.518725399999999},
#     'viewport': {'northeast': {'lat': 33.60744808029149,
#       'lng': -7.517439669708497},
#      'southwest': {'lat': 33.6047501197085, 'lng': -7.520137630291502}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#    'id': '49186e7a303025b5a59f6e82116adbefbf948dab',
#    'name': 'Pharmacie Le Rond Point',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2508,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110402018196523961467/photos">Mouhcine Boss</a>'],
#      'photo_reference': 'CmRaAAAAcN5izJ_POF5LSn1Gf4Y1VF-Ede7oahQ4Mhip-f4E2bKrwch4QBbCUwj4KmBYpZ2vw4qM3XugU4qlqOzuYN7RjhWmAx1Ii98Ly4MXrR97mlcmljgk2Y_iOTxc0hj7Tyv1EhCnaHsytrGbuQhJneJyFkmgGhSiLxCWJDvfKCpEKPLFs0aTbQ0eHw',
#      'width': 3344}],
#    'place_id': 'ChIJ7S-S8XvLpw0RSPrdd8jeRJg',
#    'plus_code': {'compound_code': 'JF4J+CG Casablanca, Maroc',
#     'global_code': '8C5JJF4J+CG'},
#    'rating': 4,
#    'reference': 'ChIJ7S-S8XvLpw0RSPrdd8jeRJg',
#    'scope': 'GOOGLE',
#    'types': ['pharmacy',
#     'health',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 5,
#    'vicinity': 'Casablanca'},
#   {'geometry': {'location': {'lat': 33.5753868, 'lng': -7.529872699999999},
#     'viewport': {'northeast': {'lat': 33.5767688802915,
#       'lng': -7.528482519708497},
#      'southwest': {'lat': 33.5740709197085, 'lng': -7.531180480291502}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#    'id': '063168d0b28f8975ae244118cc9d96cb3f6e323a',
#    'name': 'Pharmacie Mounir صيدلية منير',
#    'opening_hours': {'open_now': False},
#    'place_id': 'ChIJ_60VLKnMpw0RPETJ4uCjV5w',
#    'plus_code': {'compound_code': 'HFGC+53 Casablanca, Maroc',
#     'global_code': '8C5JHFGC+53'},
#    'rating': 3.8,
#    'reference': 'ChIJ_60VLKnMpw0RPETJ4uCjV5w',
#    'scope': 'GOOGLE',
#    'types': ['pharmacy',
#     'health',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 4,
#    'vicinity': 'Casablanca'},
#   {'geometry': {'location': {'lat': 33.5505511, 'lng': -7.602410300000002},
#     'viewport': {'northeast': {'lat': 33.55187283029149,
#       'lng': -7.601184519708499},
#      'southwest': {'lat': 33.54917486970849, 'lng': -7.603882480291504}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#    'id': 'c091684f5b432eeadeade1a06cd25d43bc91f518',
#    'name': 'Hanane',
#    'photos': [{'height': 4030,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117417532143149295081/photos">Adil Eddahabi</a>'],
#      'photo_reference': 'CmRaAAAAvuX-zHZ69OuzZf9gYgVF7MPGvQSHl4pUjcdVD7TNkYeWy1US8ryNZPVjaI5TRe_1U_yTrdO4-u64c8D9_btTPyLKLIgj5_1Nig76x3jHXb7RHmXdA944moLx0VzYEZMNEhBo1u6SnN3GtAQtf0C1YakaGhTh0mqmu5XFbIpv6d_4eYff_I9oRQ',
#      'width': 3024}],
#    'place_id': 'ChIJI_babKUypg0RYqzK6kFio4A',
#    'plus_code': {'compound_code': 'H92X+62 Casablanca, Maroc',
#     'global_code': '8C5JH92X+62'},
#    'rating': 3.5,
#    'reference': 'ChIJI_babKUypg0RYqzK6kFio4A',
#    'scope': 'GOOGLE',
#    'types': ['pharmacy',
#     'health',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 11,
#    'vicinity': 'Avenue 2 Mars, Casablanca'},
#   {'geometry': {'location': {'lat': 33.5754106, 'lng': -7.6391699},
#     'viewport': {'northeast': {'lat': 33.5767806802915,
#       'lng': -7.637858869708499},
#      'southwest': {'lat': 33.5740827197085, 'lng': -7.640556830291504}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#    'id': 'af838875cb590d83a2fffebc18dac2a4a4f21f47',
#    'name': 'Pharmacie VITA',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100035392070340772750/photos">Ahmed Amine</a>'],
#      'photo_reference': 'CmRaAAAANORkVOee-N6RHfagfqJjAy2TzNTVH9v0X_-wiVvNsXY4U3v8IySK7YnoWc0frUmrEtXpFTiJWZwK9i0LDn5AhrcMzwVTINoOS-HEJY6P2ul9KFCMIDi1LNgsljsVcKfxEhAm1Cy6HhXM4qQFFOGOM-BkGhR6BlnqvDUQbBpscl5_lwPhDJ28rA',
#      'width': 3024}],
#    'place_id': 'ChIJE5ISJcTSpw0RUUsb32VOy6M',
#    'plus_code': {'compound_code': 'H9G6+58 Casablanca, Maroc',
#     'global_code': '8C5JH9G6+58'},
#    'rating': 4.1,
#    'reference': 'ChIJE5ISJcTSpw0RUUsb32VOy6M',
#    'scope': 'GOOGLE',
#    'types': ['pharmacy',
#     'health',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 24,
#    'vicinity': 'Boulevard Brahim Roudani, Casablanca'},
#   {'geometry': {'location': {'lat': 33.52518959999999, 'lng': -7.6506042},
#     'viewport': {'northeast': {'lat': 33.5265320302915,
#       'lng': -7.649158019708499},
#      'southwest': {'lat': 33.5238340697085, 'lng': -7.651855980291502}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#    'id': '92e09d49fcead61b86d9a1e916dbacf9e659f789',
#    'name': 'Pharmacie Yaterib',
#    'place_id': 'ChIJqUqMagMtpg0R0uUK8JC9ivg',
#    'plus_code': {'compound_code': 'G8GX+3Q Casablanca, Maroc',
#     'global_code': '8C5JG8GX+3Q'},
#    'rating': 5,
#    'reference': 'ChIJqUqMagMtpg0R0uUK8JC9ivg',
#    'scope': 'GOOGLE',
#    'types': ['pharmacy',
#     'health',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': 'Casablanca'},
#   {'geometry': {'location': {'lat': 33.5840214, 'lng': -7.6204241},
#     'viewport': {'northeast': {'lat': 33.5853929802915,
#       'lng': -7.6190714697085},
#      'southwest': {'lat': 33.5826950197085, 'lng': -7.621769430291504}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#    'id': '90469e475fe2fc9ee6e9690a5a95a94c8069e19b',
#    'name': 'Yami Négoce sarl',
#    'place_id': 'ChIJuwesnaLSpw0RWhzk621Lpis',
#    'plus_code': {'compound_code': 'H9MH+JR Casablanca, Maroc',
#     'global_code': '8C5JH9MH+JR'},
#    'rating': 5,
#    'reference': 'ChIJuwesnaLSpw0RWhzk621Lpis',
#    'scope': 'GOOGLE',
#    'types': ['pharmacy',
#     'health',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': 'Rue Saad Bnou Abi Wakkas, Casablanca'},
#   {'geometry': {'location': {'lat': 33.5940984, 'lng': -7.6277182},
#     'viewport': {'northeast': {'lat': 33.59546118029149,
#       'lng': -7.626345019708496},
#      'southwest': {'lat': 33.59276321970849, 'lng': -7.629042980291501}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#    'id': '7faece771f018b17d49a79b5bd7e06fc65b69a92',
#    'name': 'pharmacie El Kandara',
#    'place_id': 'ChIJn_XcY-4ypg0RmYY5ndhvlqg',
#    'plus_code': {'compound_code': 'H9VC+JW Casablanca, Maroc',
#     'global_code': '8C5JH9VC+JW'},
#    'rating': 4,
#    'reference': 'ChIJn_XcY-4ypg0RmYY5ndhvlqg',
#    'scope': 'GOOGLE',
#    'types': ['pharmacy',
#     'health',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 3,
#    'vicinity': 'Rue Abdellah Guennoun, Casablanca'},
#   {'geometry': {'location': {'lat': 33.58908859999999, 'lng': -7.6284997},
#     'viewport': {'northeast': {'lat': 33.59039648029149,
#       'lng': -7.627180569708497},
#      'southwest': {'lat': 33.58769851970849, 'lng': -7.629878530291502}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#    'id': '320b7449628bab5fcc740dc2d430fdbbe5639bb6',
#    'name': 'Tulipe Para ( Parapharmacie Casablanca - cosmétiques - soins - beauté )',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 960,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107460150948415178734/photos">Tulipe Para ( Parapharmacie Casablanca - cosmétiques - soins - beauté )</a>'],
#      'photo_reference': 'CmRaAAAA6kF9npdV-3Po6EXNj_vzT3Xe2ZJliD4gVM-pHG60dZdRazYgftHSwe_UnJfiXeyoRKvV_rvf20qgeoy_tI_FqxABxYrBFnRqij1RwxPE6iHwvuYvJxFnAGxuib02u2BdEhD19DHdhjqWvYfVo3sW2bwJGhRoReCfw6vhRDRsV9ggL6wrbwi3yA',
#      'width': 1280}],
#    'place_id': 'ChIJ52IACZTSpw0RZW9AZIvuXk4',
#    'plus_code': {'compound_code': 'H9QC+JJ Casablanca, Maroc',
#     'global_code': '8C5JH9QC+JJ'},
#    'rating': 4.1,
#    'reference': 'ChIJ52IACZTSpw0RZW9AZIvuXk4',
#    'scope': 'GOOGLE',
#    'types': ['pharmacy',
#     'health',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 15,
#    'vicinity': '13 rue Taha Houcine - ex Galilée , Gautier, Anfa Centre Ville Maarif, Casablanca'},
#   {'geometry': {'location': {'lat': 33.58681, 'lng': -7.636709999999998},
#     'viewport': {'northeast': {'lat': 33.5881458802915,
#       'lng': -7.635361219708496},
#      'southwest': {'lat': 33.5854479197085, 'lng': -7.638059180291501}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#    'id': '9d3acd41d749425f5ebf9385f13a10499654d602',
#    'name': 'Pharmacie les Capucines',
#    'opening_hours': {'open_now': False},
#    'place_id': 'ChIJ1WBSuuvSpw0Reyxjl4IySrM',
#    'plus_code': {'compound_code': 'H9P7+P8 Casablanca, Maroc',
#     'global_code': '8C5JH9P7+P8'},
#    'rating': 4.699999999999999,
#    'reference': 'ChIJ1WBSuuvSpw0Reyxjl4IySrM',
#    'scope': 'GOOGLE',
#    'types': ['pharmacy',
#     'health',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 13,
#    'vicinity': '38 Boulevard Al Massira Al Khadra, Casablanca'},
#   {'geometry': {'location': {'lat': 33.5232935, 'lng': -7.645089600000002},
#     'viewport': {'northeast': {'lat': 33.5247089802915,
#       'lng': -7.643696619708497},
#      'southwest': {'lat': 33.5220110197085, 'lng': -7.646394580291502}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#    'id': '499e823e0c8f867a111b5dcaf3c8b2544e059b21',
#    'name': 'Pharamcie Marjana',
#    'place_id': 'ChIJ51khlwUtpg0REzFJtBVAy9k',
#    'plus_code': {'compound_code': 'G9F3+8X Casablanca, Maroc',
#     'global_code': '8C5JG9F3+8X'},
#    'rating': 5,
#    'reference': 'ChIJ51khlwUtpg0REzFJtBVAy9k',
#    'scope': 'GOOGLE',
#    'types': ['pharmacy',
#     'health',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': 'Boulevard 60, Casablanca'},
#   {'geometry': {'location': {'lat': 33.556216, 'lng': -7.605878},
#     'viewport': {'northeast': {'lat': 33.5575381302915,
#       'lng': -7.604591519708498},
#      'southwest': {'lat': 33.5548401697085, 'lng': -7.607289480291502}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#    'id': '59e5816d081ab2879594a6b13ee4b6493d5692b6',
#    'name': 'Pharmacie Oscar En GARDE',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3264,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105772563080062495200/photos">Pharmacie oscar En GARDE</a>'],
#      'photo_reference': 'CmRaAAAATRkL02WdBCNG3MKnHwN8SoqWIQs7Pa173FSJcq_xJFyi3C1nvMuL8iWNgk7OQ8TrJuyVFmRYab0Yse2bK_0A6G2b2_4jUMbEeUNSyggiKmxoZerW4q6UbKRugIjfVPWIEhA8DqyNzR68FR0BIM2KIReNGhT6ZaZ5psNZaKUSo2q0Fvvs5y83Cg',
#      'width': 1836}],
#    'place_id': 'ChIJSaR6sq4ypg0R75Zlem8AQLw',
#    'plus_code': {'compound_code': 'H94V+FJ Casablanca, Maroc',
#     'global_code': '8C5JH94V+FJ'},
#    'rating': 3.8,
#    'reference': 'ChIJSaR6sq4ypg0R75Zlem8AQLw',
#    'scope': 'GOOGLE',
#    'types': ['pharmacy',
#     'health',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 12,
#    'vicinity': 'Andalous 3 Rue 7 N 121 ain chock, Casablanca'},
#   {'geometry': {'location': {'lat': 33.5929411, 'lng': -7.5626318},
#     'viewport': {'northeast': {'lat': 33.5942906802915,
#       'lng': -7.561283019708497},
#      'southwest': {'lat': 33.5915927197085, 'lng': -7.563980980291501}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#    'id': '330c6ee82217145800d0b71ac723a448ec4569be',
#    'name': 'VERDEPHARMA PARA',
#    'photos': [{'height': 1032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103700515699353120631/photos">Fouad JAKMI</a>'],
#      'photo_reference': 'CmRaAAAAU0CHrtzsS1NSH9d2j4SK5peWwuADs___Ph86ZZE8TAdt2yd-WTjsHOj_m6a88l9BGhdEzykhqcmKG5qWa56q0fyzA2luZRLb_ugZedWn7kMOz3ObPbPKtMlm1mOrFwPCEhBhcV7lgSQJx4SMqkxrZwrNGhTCNT-2hf_WH9-QL2tvf5Io2IhkSg',
#      'width': 581}],
#    'place_id': 'ChIJT_e6-OPMpw0RZ65medGroxw',
#    'plus_code': {'compound_code': 'HCVP+5W Casablanca, Maroc',
#     'global_code': '8C5JHCVP+5W'},
#    'rating': 5,
#    'reference': 'ChIJT_e6-OPMpw0RZ65medGroxw',
#    'scope': 'GOOGLE',
#    'types': ['pharmacy',
#     'health',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 3,
#    'vicinity': 'Casablanca'},
#   {'geometry': {'location': {'lat': 33.5671877, 'lng': -7.640109799999999},
#     'viewport': {'northeast': {'lat': 33.5685351802915,
#       'lng': -7.638762069708497},
#      'southwest': {'lat': 33.5658372197085, 'lng': -7.641460030291501}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#    'id': '89e2023a1ed108d27982a1216cac8b823365eea3',
#    'name': 'Pharmacie Bouzoubaâ',
#    'photos': [{'height': 2508,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110402018196523961467/photos">Mouhcine Boss</a>'],
#      'photo_reference': 'CmRaAAAAbOXbFl-_6q1rvRNRujxfT86WY0cppUrhkPHV3UG9T_sqkF7VW14nA9xxwpAxZ0lk4H27Z0IhfgtU5C0E3kA6lTGg2cMjE6FpFaVqC5Y1ZfooZXkUJlWECr5PQiFF4flqEhD7jWiUXHfyDzTNRW6eEZFlGhQQYIS6hgrLclJgG0hILphY_zanFQ',
#      'width': 3344}],
#    'place_id': 'ChIJOcjvls7Spw0RtYpez2rvjcI',
#    'plus_code': {'compound_code': 'H985+VX Casablanca, Maroc',
#     'global_code': '8C5JH985+VX'},
#    'rating': 4.699999999999999,
#    'reference': 'ChIJOcjvls7Spw0RtYpez2rvjcI',
#    'scope': 'GOOGLE',
#    'types': ['pharmacy',
#     'health',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 15,
#    'vicinity': '285, Bd Ghandi, 20390 Quartier: Al Batha, Casablanca'},
#   {'geometry': {'location': {'lat': 33.5461038, 'lng': -7.631340600000001},
#     'viewport': {'northeast': {'lat': 33.5474371802915,
#       'lng': -7.630137869708498},
#      'southwest': {'lat': 33.5447392197085, 'lng': -7.632835830291502}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#    'id': '6cd9867a891b9ee9b026985e2c05f815dc31dbf7',
#    'name': 'Pharmacie Mekka',
#    'opening_hours': {'open_now': True},
#    'place_id': 'ChIJgThgFkctpg0Rh-r054Ez_Q4',
#    'plus_code': {'compound_code': 'G9W9+CF Casablanca, Maroc',
#     'global_code': '8C5JG9W9+CF'},
#    'rating': 5,
#    'reference': 'ChIJgThgFkctpg0Rh-r054Ez_Q4',
#    'scope': 'GOOGLE',
#    'types': ['pharmacy',
#     'health',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': '119, route de la Mecque , Californie, 20150 CASABLANCA, 119 Boulevard Panoramique, Casablanca'},
#   {'geometry': {'location': {'lat': 33.5979541, 'lng': -7.6647969},
#     'viewport': {'northeast': {'lat': 33.59903158029149,
#       'lng': -7.663419919708498},
#      'southwest': {'lat': 33.5963336197085, 'lng': -7.666117880291503}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#    'id': '77b4817f00794fc01fede14929f4b512c49a0bc5',
#    'name': 'Pharmacie AnfaPlace',
#    'opening_hours': {'open_now': True},
#    'place_id': 'ChIJR5a0AAbTpw0R8p2HivXOUYM',
#    'plus_code': {'compound_code': 'H8XP+53 Casablanca, Maroc',
#     'global_code': '8C5JH8XP+53'},
#    'rating': 3,
#    'reference': 'ChIJR5a0AAbTpw0R8p2HivXOUYM',
#    'scope': 'GOOGLE',
#    'types': ['pharmacy',
#     'health',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 6,
#    'vicinity': 'shopping center Anfaplace, Bd de la corniche, Casablanca'}],
#  'status': 'OK'}

# %%
c = 0
for i in response['results']:
    print(i['geometry']['location'])
    print(i['name'])
    
    c = c + 1
    
print("**********")
print(c)
# Out:
# {'lat': 33.59472820000001, 'lng': -7.608590100000001}
# Pharmacie Safir
# {'lat': 33.5720615, 'lng': -7.5942725}
# Pharmacie de l'Union
# {'lat': 33.5769354, 'lng': -7.636434099999999}
# Pharmacie Mehdi صيدلية مهدي
# {'lat': 33.5718648, 'lng': -7.653467500000001}
# Kenza كنزة
# {'lat': 33.5710826, 'lng': -7.660144900000001}
# Pharmacie Araucaria
# {'lat': 33.60608839999999, 'lng': -7.518725399999999}
# Pharmacie Le Rond Point
# {'lat': 33.5753868, 'lng': -7.529872699999999}
# Pharmacie Mounir صيدلية منير
# {'lat': 33.5505511, 'lng': -7.602410300000002}
# Hanane
# {'lat': 33.5754106, 'lng': -7.6391699}
# Pharmacie VITA
# {'lat': 33.52518959999999, 'lng': -7.6506042}
# Pharmacie Yaterib
# {'lat': 33.5840214, 'lng': -7.6204241}
# Yami Négoce sarl
# {'lat': 33.5940984, 'lng': -7.6277182}
# pharmacie El Kandara
# {'lat': 33.58908859999999, 'lng': -7.6284997}
# Tulipe Para ( Parapharmacie Casablanca - cosmétiques - soins - beauté )
# {'lat': 33.58681, 'lng': -7.636709999999998}
# Pharmacie les Capucines
# {'lat': 33.5232935, 'lng': -7.645089600000002}
# Pharamcie Marjana
# {'lat': 33.556216, 'lng': -7.605878}
# Pharmacie Oscar En GARDE
# {'lat': 33.5929411, 'lng': -7.5626318}
# VERDEPHARMA PARA
# {'lat': 33.5671877, 'lng': -7.640109799999999}
# Pharmacie Bouzoubaâ
# {'lat': 33.5461038, 'lng': -7.631340600000001}
# Pharmacie Mekka
# {'lat': 33.5979541, 'lng': -7.6647969}
# Pharmacie AnfaPlace
# **********
# 20

# %% [markdown]
# ** getting the next_page_token **

# %%
token = response['next_page_token']

# %%
r = requests.get(url +'pagetoken='+token+'&location=' +str(location) +'&radius='+str(radius) + '&type='+place_type+'&language='+language+'&key=' + api_key)

# %%
response2 = r.json()

# %%
print(response2)
# next page token
token2 = response2['next_page_token']
# Out:
# {'html_attributions': [], 'next_page_token': 'CsQDvAEAADihSZR50HL-SG5ss70PV9EfWA9GguP7UJFi6-i6uChOwRif-O9s-60DBPxv96hpASjhBWvMmATYqKViD5KH_K9SSHgdJlPSgO3p8dJiKQ2VPcvv0CuS5D57J2TNdsdjMj3our93KKmkf1PW1Ld1A2eN5w1D0hP-ZIArEpvAVo7E8oRdy4xCOzCkjWoFkzWEth3n_UqXN3cZ4tP9P6YP_pzWuwNSCY1VVIq-j9ci_IwOVL2SMNqEaPjXJJ6Z6wgPx086fLn734INdkTTQH8JUAisKvaY-HLr2Vb3_p8f3ugaZxR-sO_bIsDRmu0MtzvasctWhPdmcG7BmlxBbH-0aD4PX2GoC0OATWB-2B3CyQReOIhJGAedkQh9xo9z0IQYk7IvNPgXGV5r-VJRMVfHekVI3lobVLtaKpKa00kaDLiOJncPnTvRmJrf92WSaUoZMfFZmu1nyIYlF6MGASUfBUS8kFpDZVFBzIrnc9dS7isywqhW59jjOtJ7N7UtdR01Il4VwlHjBtwtOcH-cDewD9n82jeTAmLaGLKEcMefkZIDKq9CBBvF2Ydqw8aWqc418Prja4eM5Cvnhkiu_2fY0lwSEOGSqUCShgKklmmHLek4SvgaFNVCHFIxSuui4ZkpCL5QU-lShNiL', 'results': [{'geometry': {'location': {'lat': 33.5347382, 'lng': -7.6041742}, 'viewport': {'northeast': {'lat': 33.53605848029149, 'lng': -7.602946069708498}, 'southwest': {'lat': 33.53336051970849, 'lng': -7.605644030291502}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': '5b4351d3de0187f7f219a4caac30702590bc56d4', 'name': 'PHARMACIE AYA صيدلية اية', 'opening_hours': {'open_now': True}, 'place_id': 'ChIJr0N92Zsypg0Rry7AtXAy0EY', 'plus_code': {'compound_code': 'G9MW+V8 Casablanca, Maroc', 'global_code': '8C5JG9MW+V8'}, 'rating': 5, 'reference': 'ChIJr0N92Zsypg0Rry7AtXAy0EY', 'scope': 'GOOGLE', 'types': ['pharmacy', 'health', 'point_of_interest', 'store', 'establishment'], 'user_ratings_total': 1, 'vicinity': 'Kebibate, Rabat'}, {'geometry': {'location': {'lat': 33.5371609, 'lng': -7.6490633}, 'viewport': {'northeast': {'lat': 33.53849838029149, 'lng': -7.647784669708496}, 'southwest': {'lat': 33.5358004197085, 'lng': -7.650482630291501}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': '537dddd0ef255b8909f5e824671e8cd58575d377', 'name': 'Pharmacie Zenith Millenium', 'opening_hours': {'open_now': False}, 'photos': [{'height': 960, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109830194430583123225/photos">amina tahri</a>'], 'photo_reference': 'CmRaAAAA0pZoPFgXB8aj6vOBO735ZEdAoxXLxnZYp2FuPliuqXQi8cCvXWkQuuaqtVMhV9HbbIiWNAMt23aI18TvsuX5B3mXswyfsqRFtARJUhHLt0JGpg0dvhcKrLOdgVLE4etgEhBl_-tNlPKeAk8kXoMfMSNCGhRJKruo1nZ-zHUjnGgjXhc-nld_dw', 'width': 1280}], 'place_id': 'ChIJUxO_deLMpw0R83maF7eGKmc', 'plus_code': {'compound_code': 'G9P2+V9 Casablanca, Maroc', 'global_code': '8C5JG9P2+V9'}, 'rating': 4.5, 'reference': 'ChIJUxO_deLMpw0R83maF7eGKmc', 'scope': 'GOOGLE', 'types': ['pharmacy', 'health', 'point_of_interest', 'store', 'establishment'], 'user_ratings_total': 14, 'vicinity': '162 Lotissement Florida Sidi Maarouf, Casablanca'}, {'geometry': {'location': {'lat': 33.5662344, 'lng': -7.6782163}, 'viewport': {'northeast': {'lat': 33.5675579302915, 'lng': -7.676851419708497}, 'southwest': {'lat': 33.5648599697085, 'lng': -7.679549380291502}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': '471bfdccebd8d78c79ee482ec41edf00ab3827d7', 'name': 'Para Verano Medical', 'opening_hours': {'open_now': True}, 'photos': [{'height': 3456, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100338294628906246384/photos">e-commerce verano</a>'], 'photo_reference': 'CmRaAAAAF_Z5QM5mjVAQsA-JGZ2F_FIg_pXhzAlNWWKdZE4XWdT0dWGLdhrDAC8GEXbE13P9laRzEOMq_mc-vjBlOSycgc69PlfmpoHq9sptJNBllg39ICgaEkXVMbHtcsosQlnKEhB8UBL7Rnd-2EhMAFdTZjRvGhROktic1fkaa-bHe8O2AtAtlvo2zQ', 'width': 5064}], 'place_id': 'ChIJk2qJ9uzTpw0RNQihBBXVlSM', 'plus_code': {'compound_code': 'H88C+FP Casablanca, Maroc', 'global_code': '8C5JH88C+FP'}, 'rating': 4.399999999999999, 'reference': 'ChIJk2qJ9uzTpw0RNQihBBXVlSM', 'scope': 'GOOGLE', 'types': ['pharmacy', 'health', 'point_of_interest', 'store', 'establishment'], 'user_ratings_total': 12, 'vicinity': 'a cote de marjane, Casablanca'}, {'geometry': {'location': {'lat': 33.5326141, 'lng': -7.6789118}, 'viewport': {'northeast': {'lat': 33.5339950302915, 'lng': -7.677615369708498}, 'southwest': {'lat': 3 ...

# %%
r = requests.get(url +'pagetoken='+token2+'&location=' +str(location) +'&radius='+str(radius) + '&type='+place_type+'&language='+language+'&key=' + api_key)

# %%
response3 = r.json()

# %%
response3
# Out:
# {'html_attributions': [],
#  'results': [{'geometry': {'location': {'lat': 33.5750999,
#      'lng': -7.634702000000001},
#     'viewport': {'northeast': {'lat': 33.5764331302915,
#       'lng': -7.633277619708498},
#      'southwest': {'lat': 33.5737351697085, 'lng': -7.635975580291503}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#    'id': 'ab4aaa52c7fc227e57ce9bd28d9f7cac05bb8b42',
#    'name': 'Pharmacie Val Fleuri',
#    'place_id': 'ChIJ-zlJCsfSpw0RyLGjW2hsqeo',
#    'plus_code': {'compound_code': 'H9G8+24 Casablanca, Maroc',
#     'global_code': '8C5JH9G8+24'},
#    'rating': 3.1,
#    'reference': 'ChIJ-zlJCsfSpw0RyLGjW2hsqeo',
#    'scope': 'GOOGLE',
#    'types': ['pharmacy',
#     'health',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 7,
#    'vicinity': '89 Rue 89, Casablanca'},
#   {'geometry': {'location': {'lat': 33.5579945, 'lng': -7.573909199999999},
#     'viewport': {'northeast': {'lat': 33.55934918029149,
#       'lng': -7.572565469708497},
#      'southwest': {'lat': 33.55665121970849, 'lng': -7.575263430291502}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#    'id': 'acb9b4560cea73a89eaf00ad5977a0d2654f8ce1',
#    'name': 'Pharmacie El Mansour',
#    'photos': [{'height': 4608,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102499464497220977280/photos">Abdellah IGUIDER</a>'],
#      'photo_reference': 'CmRaAAAAVdFYzRi64I93O8FhiK_RG10hcZvAhFaEgukS5cuCvtphSejKQNeKrKRuoyZ6opK0BAbuc4e5l9SbspQVvqQPfViBZRqgtnoXFLek7cYzEYTLry3KeJLxZFgSIgBNEcZZEhB-r_slqNVeSsP7EtDShNIgGhTDgluKuKEKDG2cjrHXjiA21LMHiw',
#      'width': 3456}],
#    'place_id': 'ChIJA9oiSdEypg0R08Bq-aV7PbI',
#    'plus_code': {'compound_code': 'HC5G+5C Casablanca, Maroc',
#     'global_code': '8C5JHC5G+5C'},
#    'rating': 3.2,
#    'reference': 'ChIJA9oiSdEypg0R08Bq-aV7PbI',
#    'scope': 'GOOGLE',
#    'types': ['pharmacy',
#     'health',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 14,
#    'vicinity': 'Boulevard Al Joulane, Casablanca'},
#   {'geometry': {'location': {'lat': 33.590313, 'lng': -7.604042799999999},
#     'viewport': {'northeast': {'lat': 33.5916335802915,
#       'lng': -7.602711669708497},
#      'southwest': {'lat': 33.5889356197085, 'lng': -7.605409630291502}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#    'id': '6554257976b9906f87ef162f5cd75d83e6ccc9e8',
#    'name': 'Pharmacie du Soleil',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 4128,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114300594024340314291/photos">Hfs Ben</a>'],
#      'photo_reference': 'CmRaAAAAfknigfuMpvfS0O7YNoUBfHj9phdzuJHk9etVwwC7eMfH8r1BF0zWeFttIybYCimfNRLwoUxi1UN7BHh46J_gE-LazE263mm7ORFA4ZpR6-3hGAwdqhrqwEWVUo-MqjO7EhDTmYM2aepuwxjFQbFhpaUNGhQRt96Geky4h0ATuOLLlXUamkB4jw',
#      'width': 3096}],
#    'place_id': 'ChIJnYY_m2bNpw0RJ3MDx0v78Qg',
#    'plus_code': {'compound_code': 'H9RW+49 Casablanca, Maroc',
#     'global_code': '8C5JH9RW+49'},
#    'rating': 4.5,
#    'reference': 'ChIJnYY_m2bNpw0RJ3MDx0v78Qg',
#    'scope': 'GOOGLE',
#    'types': ['pharmacy',
#     'health',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 2,
#    'vicinity': 'Casablanca'},
#   {'geometry': {'location': {'lat': 33.5877863, 'lng': -7.603750799999999},
#     'viewport': {'northeast': {'lat': 33.58913588029149,
#       'lng': -7.602400269708498},
#      'southwest': {'lat': 33.58643791970849, 'lng': -7.605098230291502}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#    'id': 'f38bdbcb2d6a388f42ae66c5b3a9efc3c7fea7c9',
#    'name': 'pharmacie moulay',
#    'place_id': 'ChIJxfOxWMfNpw0RVfFCeA7NZWI',
#    'plus_code': {'compound_code': 'H9QW+4F Casablanca, Maroc',
#     'global_code': '8C5JH9QW+4F'},
#    'rating': 5,
#    'reference': 'ChIJxfOxWMfNpw0RVfFCeA7NZWI',
#    'scope': 'GOOGLE',
#    'types': ['pharmacy',
#     'health',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': 'Rue Bachir Ibrahimi, Casablanca'},
#   {'geometry': {'location': {'lat': 33.588538, 'lng': -7.601782299999999},
#     'viewport': {'northeast': {'lat': 33.5898972802915,
#       'lng': -7.600412269708498},
#      'southwest': {'lat': 33.5871993197085, 'lng': -7.603110230291502}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#    'id': 'ac3a974b4ada40cb036fc2a24afa664ffbf69166',
#    'name': 'Pharmacie Derb Omar',
#    'place_id': 'ChIJ1aRgNmbNpw0RfivSrnHjZbI',
#    'plus_code': {'compound_code': 'H9QX+C7 Casablanca, Maroc',
#     'global_code': '8C5JH9QX+C7'},
#    'rating': 2.3,
#    'reference': 'ChIJ1aRgNmbNpw0RfivSrnHjZbI',
#    'scope': 'GOOGLE',
#    'types': ['pharmacy',
#     'health',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 3,
#    'vicinity': '14, Rue Oulad Ziane, Passage Souak, 20090 Quartier: Derb Omar, Casablanca'},
#   {'geometry': {'location': {'lat': 33.59181089999999,
#      'lng': -7.601966399999999},
#     'viewport': {'northeast': {'lat': 33.5931579302915,
#       'lng': -7.600620869708497},
#      'southwest': {'lat': 33.5904599697085, 'lng': -7.603318830291502}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#    'id': 'd6edd23d6cc98a210a510495571beafcb46f23ed',
#    'name': 'Pharmacie Yassine',
#    'opening_hours': {'open_now': False},
#    'place_id': 'ChIJLQGNSmjNpw0RO_t86mCqVIo',
#    'plus_code': {'compound_code': 'H9RX+P6 Casablanca, Maroc',
#     'global_code': '8C5JH9RX+P6'},
#    'rating': 4,
#    'reference': 'ChIJLQGNSmjNpw0RO_t86mCqVIo',
#    'scope': 'GOOGLE',
#    'types': ['pharmacy',
#     'health',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': '19 Avenue de Lille, Casablanca'},
#   {'geometry': {'location': {'lat': 33.5892814, 'lng': -7.6081621},
#     'viewport': {'northeast': {'lat': 33.59059963029149,
#       'lng': -7.606804869708497},
#      'southwest': {'lat': 33.58790166970849, 'lng': -7.609502830291501}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#    'id': '78d29ca8c1c2fc46623d3cb02e188326d91cb3e0',
#    'name': 'Pharmacie La Victoire',
#    'photos': [{'height': 666,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107530581315382761553/photos">BENALI CHAKIB</a>'],
#      'photo_reference': 'CmRaAAAAXL2wvL4m_8fstd9RWMKYUE_xPmKPcxUD2VuJSXkgu7oMtBSL6K8pX0YnxcFcTWaZmmakU8V9vqYKzZdSvGO49ow-cx9luTJYtTmEcqCvMX4_hmT9Lc9K2gYBmHJIIrzREhAaRz-EpSm6pPU7jeUcNs5dGhQj3LET17BLu0SaM0yuM2jqMOJnqw',
#      'width': 1038}],
#    'place_id': 'ChIJBzNocmHNpw0RP7PMAojpkqA',
#    'plus_code': {'compound_code': 'H9QR+PP Casablanca, Maroc',
#     'global_code': '8C5JH9QR+PP'},
#    'rating': 3,
#    'reference': 'ChIJBzNocmHNpw0RP7PMAojpkqA',
#    'scope': 'GOOGLE',
#    'types': ['pharmacy',
#     'health',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': 'Boulevard de Khouribga, Casablanca'},
#   {'geometry': {'location': {'lat': 33.5935853, 'lng': -7.6040812},
#     'viewport': {'northeast': {'lat': 33.59489423029149,
#       'lng': -7.602733469708496},
#      'southwest': {'lat': 33.5921962697085, 'lng': -7.6054314302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#    'id': '7eb3586561a6e6b23fd9a91d00f5b6a2c8ed5090',
#    'name': 'Pharmacie De Caducee',
#    'photos': [{'height': 2560,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114395082477740404796/photos">محمد ياسين</a>'],
#      'photo_reference': 'CmRaAAAA8chdtoNqgO6gQocyb7TiqYjeX4j5qdxnXvb1qYz60DzXzt23-RN1TU5mH4WEMIr968P-wc3azpAxEVRaC3BZOurt66Vdi_-egGR9GKDeQJFia3iPGRRSRf0lCnu14wyzEhDRRrrYX5XF7wEcnrsK-kORGhSTuO3zZ_mdXQlL_sWAW47u1YVNcw',
#      'width': 1920}],
#    'place_id': 'ChIJRVDE92TNpw0RwJh7C6Jf-zo',
#    'plus_code': {'compound_code': 'H9VW+C9 Casablanca, Maroc',
#     'global_code': '8C5JH9VW+C9'},
#    'rating': 2.3,
#    'reference': 'ChIJRVDE92TNpw0RwJh7C6Jf-zo',
#    'scope': 'GOOGLE',
#    'types': ['pharmacy',
#     'health',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 3,
#    'vicinity': '383bis Boulevard Mohammed V, Casablanca'},
#   {'geometry': {'location': {'lat': 33.58821330000001,
#      'lng': -7.599717999999999},
#     'viewport': {'northeast': {'lat': 33.5895666802915,
#       'lng': -7.598367069708497},
#      'southwest': {'lat': 33.5868687197085, 'lng': -7.601065030291502}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#    'id': '8d790cb222c889e35949759ac028555a7fd8bca4',
#    'name': 'Pharmacie Farida',
#    'opening_hours': {'open_now': False},
#    'place_id': 'ChIJ55p-YmjNpw0RJoaOjWLUKQo',
#    'plus_code': {'compound_code': 'HCQ2+74 Casablanca, Maroc',
#     'global_code': '8C5JHCQ2+74'},
#    'rating': 5,
#    'reference': 'ChIJ55p-YmjNpw0RJoaOjWLUKQo',
#    'scope': 'GOOGLE',
#    'types': ['pharmacy',
#     'health',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 2,
#    'vicinity': '79 Boulevard Ibn Tachfine, Casablanca'},
#   {'geometry': {'location': {'lat': 33.592772, 'lng': -7.607113199999999},
#     'viewport': {'northeast': {'lat': 33.5940996802915,
#       'lng': -7.605789719708498},
#      'southwest': {'lat': 33.5914017197085, 'lng': -7.608487680291502}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#    'id': '0ad4592e415984ec827458cb9f11faf2ff488357',
#    'name': 'GRANDE PHARMACIE DU MAROC الصيدلية الكبيرة بالمغرب',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2988,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107530581315382761553/photos">BENALI CHAKIB</a>'],
#      'photo_reference': 'CmRaAAAAHp4wyhWpmtlmnbuBZIsObjq2V-ujFQo0y9Bct0RKeOu9BaGmodr5i8mm-IsOc7W5yM-pzoWiJxdIMvlaraLuaUMItfN_6HCDwpjoGIG145qVOQ6ZG8IVyNm214N12sI9EhBgjvQSX4jApCVQ5twJKIdzGhQfv7a_GUYXZCyD-Yp6CFGZSpHHgQ',
#      'width': 5312}],
#    'place_id': 'ChIJ3XmcmWPNpw0RkhdZf4bqgBk',
#    'plus_code': {'compound_code': 'H9VV+45 Casablanca, Maroc',
#     'global_code': '8C5JH9VV+45'},
#    'rating': 5,
#    'reference': 'ChIJ3XmcmWPNpw0RkhdZf4bqgBk',
#    'scope': 'GOOGLE',
#    'types': ['pharmacy',
#     'health',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 3,
#    'vicinity': '27 Rue Mohammed Diouri, Casablanca'},
#   {'geometry': {'location': {'lat': 33.5858643, 'lng': -7.6044343},
#     'viewport': {'northeast': {'lat': 33.5872113302915,
#       'lng': -7.603086769708495},
#      'southwest': {'lat': 33.5845133697085, 'lng': -7.6057847302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#    'id': 'a6d71b9fbb025f957946999457d3c97fff5e9471',
#    'name': 'Pharmacie al mechoir',
#    'opening_hours': {'open_now': False},
#    'place_id': 'ChIJ49GCaGfNpw0RO49duLMAIIw',
#    'plus_code': {'compound_code': 'H9PW+86 Casablanca, Maroc',
#     'global_code': '8C5JH9PW+86'},
#    'rating': 5,
#    'reference': 'ChIJ49GCaGfNpw0RO49duLMAIIw',
#    'scope': 'GOOGLE',
#    'types': ['pharmacy',
#     'health',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 2,
#    'vicinity': '119 Rue de Libourne, Casablanca 20250 Rue de Libourne, Casablanca'},
#   {'geometry': {'location': {'lat': 33.593475, 'lng': -7.601689999999998},
#     'viewport': {'northeast': {'lat': 33.5948347302915,
#       'lng': -7.600340519708499},
#      'southwest': {'lat': 33.5921367697085, 'lng': -7.603038480291503}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#    'id': '1ebe716c01de64db55aa28d08bcb2fe5585a196f',
#    'name': 'Pharma Self',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 390,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102069723493541510323/photos">Mohamed Rayan Benzouina</a>'],
#      'photo_reference': 'CmRaAAAAX4y4UdzVvk3IYniOJQql_OWwdXlHn5I5SDu_muq7d_CK9zmiK_poCssT5x4zV6TtkVcf2WYYxnhrOxMizI-x7-LSmIuxjQfFBvZ93X4tL2ULOhATGjxCm_AE2rccdrfyEhCDBFLu2x5sAofMoYj9uQ8aGhST9kFzBhJSF-rcPkkfNquco48_gw',
#      'width': 552}],
#    'place_id': 'ChIJOXXznmXNpw0RS6kZfssYnWU',
#    'plus_code': {'compound_code': 'H9VX+98 Casablanca, Maroc',
#     'global_code': '8C5JH9VX+98'},
#    'rating': 4,
#    'reference': 'ChIJOXXznmXNpw0RS6kZfssYnWU',
#    'scope': 'GOOGLE',
#    'types': ['pharmacy',
#     'health',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 2,
#    'vicinity': '383 Boulevard Mohammed V, Assoukhour Assawda'},
#   {'geometry': {'location': {'lat': 33.58580689999999,
#      'lng': -7.604408899999999},
#     'viewport': {'northeast': {'lat': 33.58718453029149,
#       'lng': -7.603038869708496},
#      'southwest': {'lat': 33.5844865697085, 'lng': -7.605736830291501}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#    'id': 'df262534369e0d9102579d9ab14f1c54338ef504',
#    'name': 'Pharmacie Al Mechouar',
#    'photos': [{'height': 2214,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110402018196523961467/photos">Mouhcine Boss</a>'],
#      'photo_reference': 'CmRaAAAAJQj7s_K6PIrb_4j-phXyRkmZqUHyGzC32egCip16tb6bP7euundLXDsuY9-Q987E92NNrg0kaZ5aWJjw0bTcHM8B8tGPE5wRJtaQRYcoIK8-GYwW1oIlYQjBE6yMlIZqEhC4lSNIzTYadUfZ-I9WLrVeGhQmrMWBREIXirnRhUnrrUpuE0YZGw',
#      'width': 2952}],
#    'place_id': 'ChIJ5SvjCfjNpw0RDwVeXG-lYfE',
#    'plus_code': {'compound_code': 'H9PW+86 Casablanca, Maroc',
#     'global_code': '8C5JH9PW+86'},
#    'rating': 4,
#    'reference': 'ChIJ5SvjCfjNpw0RDwVeXG-lYfE',
#    'scope': 'GOOGLE',
#    'types': ['pharmacy',
#     'health',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 2,
#    'vicinity': '119 Rue de Libourne, Casablanca'},
#   {'geometry': {'location': {'lat': 33.5863719, 'lng': -7.607355400000001},
#     'viewport': {'northeast': {'lat': 33.58773583029151,
#       'lng': -7.605981019708499},
#      'southwest': {'lat': 33.58503786970851, 'lng': -7.608678980291503}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#    'id': '16e9b86aaed8279e6a7af3a12db298032d7d8adc',
#    'name': 'Pharmacie',
#    'photos': [{'height': 3096,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107284135366594681656/photos">vienoir pains</a>'],
#      'photo_reference': 'CmRaAAAA-YuW0iTktYed3bpo08PIp9Ig9WJ7ueew89fghgk1Jfv1j2IOnQM0DspqIEJNRIh8SQk3Dj-pAvbJVdxR3Q339B8zKTJRjjgtaTOIPAs9PQGsTARPiH18dOJuON3aSv1FEhCNa9PirMEVJOxz6pZGu2wyGhRHD5SLckhikDNW9Dao_Wi_Mo-ymQ',
#      'width': 4128}],
#    'place_id': 'ChIJVVVVlWDNpw0RdNFwbmSp25o',
#    'plus_code': {'compound_code': 'H9PV+G3 Casablanca, Maroc',
#     'global_code': '8C5JH9PV+G3'},
#    'rating': 5,
#    'reference': 'ChIJVVVVlWDNpw0RdNFwbmSp25o',
#    'scope': 'GOOGLE',
#    'types': ['pharmacy',
#     'health',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': 'Casablanca'},
#   {'geometry': {'location': {'lat': 33.5869877, 'lng': -7.6080889},
#     'viewport': {'northeast': {'lat': 33.5883650802915,
#       'lng': -7.606752719708497},
#      'southwest': {'lat': 33.5856671197085, 'lng': -7.609450680291501}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#    'id': '81a39ab477b4717c6ca6ce8b64f2b0e4df541d98',
#    'name': 'Pharmacie 15 Ramadan',
#    'opening_hours': {'open_now': True},
#    'place_id': 'ChIJiVoO8GDNpw0RQWiXxAiphC8',
#    'plus_code': {'compound_code': 'H9PR+QQ Casablanca, Maroc',
#     'global_code': '8C5JH9PR+QQ'},
#    'rating': 4.5,
#    'reference': 'ChIJiVoO8GDNpw0RQWiXxAiphC8',
#    'scope': 'GOOGLE',
#    'types': ['pharmacy',
#     'health',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 6,
#    'vicinity': 'Casablanca'},
#   {'geometry': {'location': {'lat': 33.5934637, 'lng': -7.6004148},
#     'viewport': {'northeast': {'lat': 33.5947803302915,
#       'lng': -7.599068319708497},
#      'southwest': {'lat': 33.5920823697085, 'lng': -7.601766280291502}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#    'id': '01b266b0426bbf6af7a69534e0906042ef14784d',
#    'name': 'Pharmacie Centre',
#    'opening_hours': {'open_now': True},
#    'place_id': 'ChIJt0Jifm_Npw0RE3CE1DFxH4g',
#    'plus_code': {'compound_code': 'H9VX+9R Casablanca, Maroc',
#     'global_code': '8C5JH9VX+9R'},
#    'rating': 5,
#    'reference': 'ChIJt0Jifm_Npw0RE3CE1DFxH4g',
#    'scope': 'GOOGLE',
#    'types': ['pharmacy',
#     'health',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 3,
#    'vicinity': 'Boulevard Mohammed V, Casablanca'},
#   {'geometry': {'location': {'lat': 33.5916704, 'lng': -7.598429900000001},
#     'viewport': {'northeast': {'lat': 33.5930225302915,
#       'lng': -7.597044619708498},
#      'southwest': {'lat': 33.5903245697085, 'lng': -7.599742580291502}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#    'id': 'ca1084df6cf780598cb25d0eea78903c0539cb0f',
#    'name': 'pharmacie Albert 1',
#    'place_id': 'ChIJ4aIk14XNpw0RTeRjQ7eecw4',
#    'plus_code': {'compound_code': 'HCR2+MJ Casablanca, Maroc',
#     'global_code': '8C5JHCR2+MJ'},
#    'rating': 5,
#    'reference': 'ChIJ4aIk14XNpw0RTeRjQ7eecw4',
#    'scope': 'GOOGLE',
#    'types': ['pharmacy',
#     'health',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': '30 Rue de Craonne, Casablanca'},
#   {'geometry': {'location': {'lat': 33.5937498, 'lng': -7.608086300000001},
#     'viewport': {'northeast': {'lat': 33.59507283029149,
#       'lng': -7.606738819708498},
#      'southwest': {'lat': 33.59237486970849, 'lng': -7.609436780291502}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#    'id': '34b3ef96762960dcc505a47d66dab1c06d8177db',
#    'name': 'Pharmacie Du Marché Central',
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105255652957116252318/photos">Lazer Fuchs</a>'],
#      'photo_reference': 'CmRaAAAAOq3oaQeFMJ0Nluf_RLwH9L-qiqk-Vu-bTh1M77vNWjpQeAPi3-qXk50-UbwgozxpR3FBW0Lm4mmjnGMfgws82298aCit0sXtLJ8O-qPJO4DOrB5DhCL_GaYEGeqhQ-IJEhCS79GO9HNFGOSXlGpea2wOGhT4iEM19Ggunqv8OdsQwITGeonbeg',
#      'width': 3024}],
#    'place_id': 'ChIJ6_-QBWPNpw0RUSWlsDSKX2I',
#    'plus_code': {'compound_code': 'H9VR+FQ Casablanca, Maroc',
#     'global_code': '8C5JH9VR+FQ'},
#    'rating': 5,
#    'reference': 'ChIJ6_-QBWPNpw0RUSWlsDSKX2I',
#    'scope': 'GOOGLE',
#    'types': ['pharmacy',
#     'health',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': '152 Boulevard Mohammed V, Casablanca'},
#   {'geometry': {'location': {'lat': 33.5949141, 'lng': -7.601372699999999},
#     'viewport': {'northeast': {'lat': 33.5962632802915,
#       'lng': -7.600023719708497},
#      'southwest': {'lat': 33.5935653197085, 'lng': -7.602721680291501}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#    'id': '7de71e1881aefbd52ea024cdde8adaf6086cfe64',
#    'name': "Mutuelle de l'Office d'Exploitation des Ports (MODEP)",
#    'opening_hours': {'open_now': True},
#    'place_id': 'ChIJWYdYaGXNpw0RXfxfVbnsh3c',
#    'plus_code': {'compound_code': 'H9VX+XF Casablanca, Maroc',
#     'global_code': '8C5JH9VX+XF'},
#    'rating': 4.5,
#    'reference': 'ChIJWYdYaGXNpw0RXfxfVbnsh3c',
#    'scope': 'GOOGLE',
#    'types': ['pharmacy',
#     'health',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 4,
#    'vicinity': '1 rue avesnès Angle rue Albert 1er, Quartier de la gare, Casablanca'},
#   {'geometry': {'location': {'lat': 33.5865023, 'lng': -7.598498599999998},
#     'viewport': {'northeast': {'lat': 33.5878707302915,
#       'lng': -7.597128669708496},
#      'southwest': {'lat': 33.5851727697085, 'lng': -7.599826630291501}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#    'id': 'e36c238eba7f648c18ac54b799852aca6a7077a3',
#    'name': 'Pharmacie Ilham',
#    'photos': [{'height': 1881,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110402018196523961467/photos">Mouhcine Boss</a>'],
#      'photo_reference': 'CmRaAAAAOIP_vpci1wBp9gI4nBmDOEOKbeGozSWKkHa4I7RJuMwhAUtPh05UzKgy6oG7zZTCjSoJJxLga3diHa8zvDTPZ6tXsOTObgHBtmHkeRTplyF9qIOB8eG6dt-QomecEvQfEhC7MYU7f0gJR0JMOJnfaokjGhTbfaeqHzDjm8jDJi04bmGZL92JSw',
#      'width': 3344}],
#    'place_id': 'ChIJL6K8MGjNpw0RuZK8sKlaTLA',
#    'plus_code': {'compound_code': 'HCP2+JJ Casablanca, Maroc',
#     'global_code': '8C5JHCP2+JJ'},
#    'rating': 3.8,
#    'reference': 'ChIJL6K8MGjNpw0RuZK8sKlaTLA',
#    'scope': 'GOOGLE',
#    'types': ['pharmacy',
#     'health',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 4,
#    'vicinity': 'Casablanca'}],
#  'status': 'OK'}
